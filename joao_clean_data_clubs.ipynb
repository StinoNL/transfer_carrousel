# %%
import pandas as pd
import numpy as np
import os

# Load the dataset
df_clubs = pd.read_csv("raw_data/clubs.csv")

# Show first rows
df_clubs.head()
# Out:
#    club_id          club_code                             name  \
# 0      105    sv-darmstadt-98                  SV Darmstadt 98
# 1    11127  ural-ekaterinburg               Ural Yekaterinburg
# 2      114  besiktas-istanbul        Beşiktaş Jimnastik Kulübü
# 3       12             as-rom       Associazione Sportiva Roma
# 4      148  tottenham-hotspur  Tottenham Hotspur Football Club
#
#   domestic_competition_id  total_market_value  squad_size  average_age  \
# 0                      L1                 NaN          27         25.6
# 1                     RU1                 NaN          30         26.5
# 2                     TR1                 NaN          30         26.6
# 3                     IT1                 NaN          26         26.3
# 4                     GB1                 NaN          30         25.5
#
#    foreigners_number  foreigners_percentage  national_team_players  \
# 0                 13                   48.1                      1
# 1                 11                   36.7                      3
# 2                 15                   50.0                      8
# 3                 18                   69.2                     17
# 4                 21                   70.0                     18
#
#                      stadium_name  stadium_seats net_transfer_record  \
# 0  Merck-Stadion am Böllenfalltor          17810             +€3.05m
# 1             Yekaterinburg Arena          23000              +€880k
# 2                   Beşiktaş Park          42445            €-25.26m
# 3                Olimpico di Roma          70634            €-76.90m
# 4       Tottenham Hotspur Stadium          62850           €-120.05m
#
#    coach_name  last_season                                           filename  \
# 0         NaN         2023  ../data/raw/transfermarkt-scraper/2023/clubs.j...
# 1         NaN         2023  ../data/raw/transfermarkt-scraper/2023/clubs.j...
# 2         NaN         2024  ../data/raw/transfermarkt-scraper/2024/clubs.j...
# 3         NaN         2024  ../data/raw/transfermarkt-scraper/2024/clubs.j...
# 4         NaN         2024  ../data/raw/transfermarkt-scraper/2024/clubs.j...
#
#                                                  url
# 0  https://www.transfermarkt.co.uk/sv-darmstadt-9...
# 1  https://www.transfermarkt.co.uk/ural-ekaterinb...
# 2  https://www.transfermarkt.co.uk/besiktas-istan...
# 3  https://www.transfermarkt.co.uk/as-rom/startse...
# 4  https://www.transfermarkt.co.uk/tottenham-hots...

# %%
# shape of the DataFrame
df_clubs.shape

# data types and missing values
df_clubs.info()

# counting missing values
df_clubs.isna().sum()

# basic statistics
df_clubs.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 439 entries, 0 to 438
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   club_id                  439 non-null    int64
#  1   club_code                439 non-null    object
#  2   name                     439 non-null    object
#  3   domestic_competition_id  439 non-null    object
#  4   total_market_value       0 non-null      float64
#  5   squad_size               439 non-null    int64
#  6   average_age              401 non-null    float64
#  7   foreigners_number        439 non-null    int64
#  8   foreigners_percentage    390 non-null    float64
#  9   national_team_players    439 non-null    int64
#  10  stadium_name             439 non-null    object
#  11  stadium_seats            439 non-null    int64
#  12  net_transfer_record      439 non-null    object
#  13  coach_name               0 non-null      float64
#  14  last_season              439 non-null    int64
#  15  filename                 439 non-null    object
#  16  url                      439 non-null    object
# dtypes: float64(4), int64(6), object(7)
# memory usage: 58.4+ KB
#               club_id        club_code             name  \
# count      439.000000              439              439
# unique            NaN              439              439
# top               NaN  sv-darmstadt-98  SV Darmstadt 98
# freq              NaN                1                1
# mean      6283.476082              NaN              NaN
# std      14588.760049              NaN              NaN
# min          3.000000              NaN              NaN
# 25%        435.500000              NaN              NaN
# 50%       1158.000000              NaN              NaN
# 75%       3575.000000              NaN              NaN
# max     110302.000000              NaN              NaN
#
#        domestic_competition_id  total_market_value  squad_size  average_age  \
# count                      439                 0.0  439.000000   401.000000
# unique                      14                 NaN         NaN          NaN
# top                        TR1                 NaN         NaN          NaN
# freq                        42                 NaN         NaN          NaN
# mean                       NaN                 NaN   24.184510    25.616459
# std                        NaN                 NaN    8.692365     2.059485
# min                        NaN                 NaN    0.000000     0.000000
# 25%                        NaN                 NaN   24.000000    24.600000
# 50%                        NaN                 NaN   26.000000    25.800000
# 75%                        NaN                 NaN   29.000000    26.800000
# max                        NaN                 NaN   41.000000    29.900000
#
#         foreigners_number  foreigners_percentage  national_team_players  \
# count          439.000000             390.000000             439.000000
# unique                NaN                    NaN                    NaN
# top                   NaN                    NaN                    NaN
# freq                  NaN                    NaN                    NaN
# mean            11.186788              46.582564               4.751708
# std              6.807645              20.274257               4.896634
# min              0.000000               2.400000               0.000000
# 25%              6.000000              30.800000               1.000000
# 50%             12.000000              48.050000               3.000000
# 75%             16.000000              62.400000               7.000000
# max             29.000000             100.000000              22.000000
#
#                       stadium_name  stadium_seats net_transfer_record  \
# count                          439     439.000000                 439
# unique                         420            NaN                 305
# top     Valeriy Lobanovsky Stadion            NaN                 +-0
# freq                             2            NaN                 100
# mean                           NaN   24204.091116                 NaN
# std                            NaN   17230.554384                 NaN
# min                            NaN       0.000000                 NaN
# 25%                            NaN   10815.000000                 NaN
# 50%                            NaN   20087.000000                 NaN
# 75%                            NaN   32392.000000                 NaN
# max                            NaN   81365.000000                 NaN
#
#         coach_name  last_season  \
# count          0.0   439.000000
# unique         NaN          NaN
# top            NaN          NaN
# freq           NaN          NaN
# mean           NaN  2021.526196
# std            NaN     3.563978
# min            NaN  2012.000000
# 25%            NaN  2020.000000
# 50%            NaN  2024.000000
# 75%            NaN  2024.000000
# max            NaN  2024.000000
#
#                                                  filename  \
# count                                                 439
# unique                                                 13
# top     ../data/raw/transfermarkt-scraper/2024/clubs.j...
# freq                                                  237
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                       url
# count                                                 439
# unique                                                439
# top     https://www.transfermarkt.co.uk/sv-darmstadt-9...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %%
# checking for duplicates
print("Duplicates:", df_clubs.duplicated().sum())

# dropping duplicate rows
df_clubs.drop_duplicates(inplace=True)
# Out:
# Duplicates: 0

# %%
# checking missing values
missing = df_clubs.isna().sum().sort_values(ascending=False)
print("Missing values:\n", missing[missing > 0])
# Out:
# Missing values:
#  total_market_value       439
# coach_name               439
# foreigners_percentage     49
# average_age               38
# dtype: int64

# %%
#keeping only relevant columns
df_clubs = df_clubs[["club_id", "club_code", "name","domestic_competition_id", "last_season"]]

# %%
# cleaning column names: lowercase, replace spaces with underscores
df_clubs.columns = (
    df_clubs.columns
    .str.strip()
    .str.lower()
    .str.replace(' ', '_')
    .str.replace(r'[^\w_]', '', regex=True)
)

df_clubs.columns  # Check new column names
# Out:
# Index(['club_id', 'club_code', 'name', 'domestic_competition_id',
#        'last_season'],
#       dtype='object')

# %%
# defining which text columns to clean
text_columns = [
    'name'
]

# and cleaning them
for col in text_columns:
    df_clubs[col] = df_clubs[col].astype(str).str.strip().str.title()

# %%
# and just to confirm changes
df_clubs.dtypes
# Out:
# club_id                     int64
# club_code                  object
# name                       object
# domestic_competition_id    object
# last_season                 int64
# dtype: object

# %%
import os

# create the directory
os.makedirs("clean_data", exist_ok=True)

# %%
df_clubs.to_csv("clean_data/j_clean_clubs.csv", index=False)

# %%
df_clubs.head()
# Out:
#    club_id          club_code                             name  \
# 0      105    sv-darmstadt-98                  Sv Darmstadt 98
# 1    11127  ural-ekaterinburg               Ural Yekaterinburg
# 2      114  besiktas-istanbul        Beşiktaş Jimnastik Kulübü
# 3       12             as-rom       Associazione Sportiva Roma
# 4      148  tottenham-hotspur  Tottenham Hotspur Football Club
#
#   domestic_competition_id  last_season
# 0                      L1         2023
# 1                     RU1         2023
# 2                     TR1         2024
# 3                     IT1         2024
# 4                     GB1         2024
