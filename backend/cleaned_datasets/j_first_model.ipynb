# %%
import pandas as pd
from sklearn.model_selection import train_test_split, cross_validate, cross_val_score
from sklearn.linear_model import LinearRegression

# Load the dataset
df_first_dataset = pd.read_csv("first_dataset/j_first_attempt.csv")

# Show first rows
df_first_dataset.head()
# Out:
#    player_id          player_name  club_id  \
# 0       3333         James Milner     1237
# 1       5336  Anastasios Tsokanis    60949
# 2       7161        Jonas Hofmann       15
# 3       7825           Pepe Reina     1047
# 4      11530        Lionel Carole     3205
#
#                                 club_name   age    position  \
# 0  Brighton And Hove Albion Football Club  39.0    Midfield
# 1        Volou Neos Podosferikos Syllogos  34.0    Midfield
# 2             Bayer 04 Leverkusen Fußball  33.0    Midfield
# 3                             Calcio Como  43.0  Goalkeeper
# 4                      Kayserispor Kulübü  34.0    Defender
#
#    market_value_in_eur  minutes_played  goals  assists
# 0            1000000.0             172      0        0
# 1             300000.0             923      0        0
# 2            3000000.0             545      2        2
# 3             600000.0             990      0        0
# 4             400000.0            1798      0        0

# %%
#checking the shape of the dataset
df_first_dataset.shape
# Out:
# (6400, 10)

# %%
# checking missing values
missing = df_first_dataset.isna().sum().sort_values(ascending=False)
print("Missing values:\n", missing[missing > 0])
# Out:
# Missing values:
#  age                    337
# position               337
# market_value_in_eur    337
# club_name              101
# dtype: int64

# %%
# dropping rows missing essential information
df_first_dataset = df_first_dataset.dropna(subset=["age", "position", "market_value_in_eur"])

# %%
# checking missing values
missing = df_first_dataset.isna().sum().sort_values(ascending=False)
print("Missing values:\n", missing[missing > 0])
# Out:
# Missing values:
#  club_name    101
# dtype: int64

# %%
#checking the shape of the dataset
df_first_dataset.shape
# Out:
# (6063, 10)

# %%
X = df_first_dataset[['age', 'minutes_played']]
y = df_first_dataset['market_value_in_eur']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
cv_score = cross_val_score(model, 
                           X_train, y_train, 
                           scoring='r2', 
                           cv=5)

cv_score
# Out:
# array([0.20212036, 0.17578011, 0.18653857, 0.22323994, 0.21343751])

# %%
cv_results = cross_validate(model,
                            X_train, y_train, 
                            scoring=['r2'], 
                            cv=5)

cv_results
# Out:
# {'fit_time': array([0.00099993, 0.00099993, 0.00100136, 0.00100732, 0.00100064]),
#  'score_time': array([0.00099993, 0.00099921, 0.        , 0.        , 0.00099945]),
#  'test_r2': array([0.20212036, 0.17578011, 0.18653857, 0.22323994, 0.21343751])}
